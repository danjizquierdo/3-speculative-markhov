# %%
from scraper import Scraper
import csv
import pandas as pd
import json
import numpy as np
import re

# %%
scraper=Scraper('fantasy')

# %%
titles,descriptions=scraper.go_scrape()

# %%
scraper=Scraper('sci-fi')

# %%
titles,descriptions=scraper.go_scrape()

# %%
scraper=Scraper('speculative')

# %%
titles,descriptions=scraper.go_scrape()

# %%
df=pd.read_csv('titles.csv')

# %%
df1=pd.read_csv('sci-fi-titles.csv')

# %%
df2=pd.read_csv('spec-titles.csv')

# %%
titles_df=df.append(df1.append(df2))

# %%
titles_df.head()
# Out:
#    Unnamed: 0                                                  0
# 0           0     The Hobbit or There and Back Again (Paperback)
# 1           1       The Ocean at the End of the Lane (Hardcover)
# 2           2  The Lion, the Witch and the Wardrobe (Chronicl...
# 3           3  Harry Potter and the Deathly Hallows (Harry Po...
# 4           4      A Darker Shade of Magic (Shades of Magic, #1)

# %%
corpus=titles_df['0'].str.split()

# %%
def pair_up(corpus):
    for word in range(len(corpus)-1):
        yield (corpus[word], corpus[word+1])

# %%
pairs=pair_up(d_corpus)

# %%
pairs
# Out:
# <generator object pair_up at 0x12ac09b10>

# %%
titles_dict={}

# %%
for prior,posterior in pairs:
    if prior in titles_dict.keys():
        titles_dict[prior].append(posterior)
    else:
        titles_dict[prior]=[posterior]

# %%
titles_dict
# Out:
# {'Hobbit': ['or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or',
#   'or'],
#  'or': ['There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
#   'There',
# ...

# %%
df=pd.read_csv('./csvs/fantasy-descriptions.csv')
df1=pd.read_csv('./csvs/sci-fi-descriptions.csv')
df2=pd.read_csv('./csvs/spec-descriptions.csv')
description_df=df.append(df1.append(df2))

# %%
corpus=description_df['0'].str.split()
d_corpus=''
for description in corpus:
    book=' '.join(description).replace('/','').replace('\\','').replace('"','').replace('-','')
    book=re.sub(r'([a-z./])([A-Z]{1})',r'\1 \2',book)
    d_corpus+=book
d_corpus=d_corpus.split()

# %%
print(d_corpus[:100])
# Out:
# ['In', 'a', 'hole', 'in', 'the', 'ground', 'there', 'lived', 'a', 'hobbit.', 'Not', 'a', 'nasty,', 'dirty,', 'wet', 'hole,', 'filled', 'with', 'the', 'ends', 'of', 'worms', 'and', 'an', 'oozy', 'smell,', 'nor', 'yet', 'a', 'dry,', 'bare,', 'sandy', 'hole', 'with', 'nothing', 'in', 'it', 'to', 'sit', 'down', 'on', 'or', 'to', 'eat:', 'it', 'was', 'a', 'hobbit-hole,', 'and', 'that', 'means', 'comfort.Written', 'for', 'J.R.R.', 'Tolkien’s', 'own', 'children,', 'The', 'Hobbit', 'met', 'with', 'instant', 'critical', 'acclaim', 'when', 'it', 'was', 'first', 'published', 'in', '1937.', 'Now', 'recognized', 'as', 'a', 'timeless', 'classic,', 'this', 'introduction', 'to', 'the', 'hobbit', 'Bilbo', 'Baggins,', 'the', 'wizard', 'Gandalf,', 'Gollum,', 'and', 'the', 'spectacular', 'world', 'of', 'Middle-earth', 'recounts', 'of', 'the', 'adventures', 'of', 'a']

# %%
description_dict={}

# %%
for prior,posterior in pairs:
    if prior in description_dict.keys():
        description_dict[prior].append(posterior)
    else:
        description_dict[prior]=[posterior]

# %%
description_dict
# Out:
# {'In': ['a',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'a',
# ...

# %%
import json
with open('titles.json','w') as fp:
    json.dump(titles_dict,fp)

# %%
with open('description.json','w') as fp:
    json.dump(description_dict,fp)

# %%
with open('./jsons/titles.json') as f:
    t_df = json.load(f)

# %%
with open('./jsons/description.json') as f:
    d_df = json.load(f)

# %%
beginning=np.random.choice(d_corpus)
print(beginning)
while beginning.islower():
    beginning=np.random.choice(d_corpus)
chain=[beginning]
n_words = 100
for i in range(n_words):
    next_word=np.random.choice(description_dict[chain[-1]])
    if bool(re.search(r'.*[\.?!]$',chain[-1])):
        while next_word.islower():
            next_word=np.random.choice(description_dict[chain[-1]])
    chain.append(next_word)
' '.join(chain)
# Out:
# emotion
# "But Harry Potter, he's stuck with news of this world's digital confines, puzzles hidden within the universe.In reality, Hiro Protagonist delivers equal parts were crafted by the cultivation of novels that he’s alive—and even if she will have grown rather fond of Earth's fate hinges on an assassination attempt, comes from which nanotechnology affects all to life...a new world entire,” are proliferating: the kitchen for the second nature. Without really are—and where, when kings clash, the University and despair, between staying with no welcome the pond (a pond that will rest until he is to make it is a past and"
